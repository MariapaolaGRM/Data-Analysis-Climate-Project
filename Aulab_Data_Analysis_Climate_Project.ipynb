# %% [markdown]
# # **Climate Project**

# %%
# Importazione librerie
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

import seaborn as sns
sns.set_theme()

# %% [markdown]
# ## **Esplorazione dei Dati su le Emissioni di Gas Serra dei Paesi del’Unione Europea**
#
# Dati mondiali sulla qualità dellʼaria dal 1990 al 2023.

# %%
# Caricamento dei dataset gas
datasets = {
    'CH4': 'Dataset/emission_dataset(1970-2023)/CH4_Emissions.csv',
    'CO2': 'Dataset/emission_dataset(1970-2023)/CO2_Emissions.csv',
    'GHG':'Dataset/emission_dataset(1970-2023)/GHG_Emissions.csv',
    'N2O': 'Dataset/emission_dataset(1970-2023)/N2O_Emissions.csv',
    'NOx': 'Dataset/emission_dataset(1970-2023)/NOx_Emissions.csv',
    'SO2': 'Dataset/emission_dataset(1970-2023)/SO2_emissions.csv'
}

def load_datasets(dict_paths):
  '''Carica più dataset da un elenco di percorsi.'''
  datasets = {}
  for name, path in dict_paths.items():
    try:
      df = pd.read_csv(path)
      datasets[name] = df
      print(f"Il dataset {name} è stato caricato con successo. Righe: {df.shape[0]}")
    except FileNotFoundError:
      print(f"Il file {path} non è stato trovato.")
  return datasets

# Dizionario contenente i dataframe caricati
df_emissions = load_datasets(datasets)
# Out:
# Il dataset CH4 è stato caricato con successo. Righe: 190
# Il dataset CO2 è stato caricato con successo. Righe: 191
# Il dataset GHG è stato caricato con successo. Righe: 192
# Il dataset N2O è stato caricato con successo. Righe: 189
# Il dataset NOx è stato caricato con successo. Righe: 228
# Il dataset SO2 è stato caricato con successo. Righe: 144

# %%
# Esplorazione dati
df_emissions['CH4'].head()
# Out:
#                Country     1990     1991     1992     1993      1994     1995  \
# 0          Afghanistan      NaN      NaN      NaN      NaN       NaN      NaN
# 1              Albania  1143.87  1183.56  1161.72  1256.43   1309.77  1313.34
# 2              Algeria      NaN      NaN      NaN      NaN  18753.00      NaN
# 3               Angola      NaN      NaN      NaN      NaN       NaN      NaN
# 4  Antigua and Barbuda    98.91      NaN      NaN      NaN       NaN      NaN
#
#       1996     1997     1998  ...     2014     2015     2016     2017  \
# 0      NaN      NaN      NaN  ...      NaN      NaN      NaN      NaN
# 1  1573.32  1602.93  1617.21  ...  1984.17  1984.17  1984.16  1984.17
# 2      NaN      NaN      NaN  ...      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN  ...      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN  ...      NaN      NaN      NaN      NaN
#
#       2018    2019    2020    2021     2022     2023
# 0      NaN     NaN     NaN     NaN      NaN      NaN
# 1  1984.17  1441.8  883.46  847.66  1513.89  1138.08
# 2      NaN     NaN     NaN     NaN      NaN      NaN
# 3      NaN     NaN     NaN     NaN      NaN      NaN
# 4      NaN     NaN     NaN     NaN      NaN      NaN
#
# [5 rows x 35 columns]

# %%
df_emissions['CO2'].head()
# Out:
#                Country     1990    1991     1992     1993      1994     1995  \
# 0          Afghanistan      NaN     NaN      NaN      NaN       NaN      NaN
# 1              Albania  3101.66  5166.7  3311.06  3235.47   3500.49  3477.42
# 2              Algeria      NaN     NaN      NaN      NaN  63705.00      NaN
# 3               Angola      NaN     NaN      NaN      NaN       NaN      NaN
# 4  Antigua and Barbuda   288.14     NaN      NaN      NaN       NaN      NaN
#
#       1996     1997     1998  ...     2014     2015     2016     2017  \
# 0      NaN      NaN      NaN  ...      NaN      NaN      NaN      NaN
# 1  3341.56  3426.64  4139.06  ...  5942.57  5942.57  5942.56  5942.57
# 2      NaN      NaN      NaN  ...      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN  ...      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN  ...      NaN      NaN      NaN      NaN
#
#       2018     2019     2020     2021     2022     2023
# 0      NaN      NaN      NaN      NaN      NaN      NaN
# 1  5942.56  8715.51  5280.94  5239.62  9151.29  8798.25
# 2      NaN      NaN      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN
#
# [5 rows x 35 columns]

# %%
df_emissions['GHG'].head()
# Out:
#                Country     1990     1991     1992    1993     1994     1995  \
# 0          Afghanistan      NaN      NaN      NaN     NaN      NaN      NaN
# 1              Albania  4341.63  6486.66  4581.28  4588.0  4906.36  4883.76
# 2              Algeria      NaN      NaN      NaN     NaN      NaN      NaN
# 3               Angola      NaN      NaN      NaN     NaN      NaN      NaN
# 4  Antigua and Barbuda      NaN      NaN      NaN     NaN      NaN      NaN
#
#       1996     1997     1998  ...     2014    2015    2016    2017     2018  \
# 0      NaN      NaN      NaN  ...      NaN     NaN     NaN     NaN      NaN
# 1  4998.58  5107.07  5830.67  ...  8125.69  8125.7  8125.7  8125.7  8125.69
# 2      NaN      NaN      NaN  ...      NaN     NaN     NaN     NaN      NaN
# 3      NaN      NaN      NaN  ...      NaN     NaN     NaN     NaN      NaN
# 4      NaN      NaN      NaN  ...      NaN     NaN     NaN     NaN      NaN
#
#       2019     2020     2021      2022      2023
# 0      NaN      NaN      NaN       NaN       NaN
# 1  9921.61  5743.87  6580.85  10417.69  10031.01
# 2      NaN      NaN      NaN       NaN       NaN
# 3      NaN      NaN      NaN       NaN       NaN
# 4      NaN      NaN      NaN       NaN       NaN
#
# [5 rows x 35 columns]

# %%
df_emissions['N2O'].head()
# Out:
#                Country   1990   1991   1992  1993     1994  1995  1996  1997  \
# 0          Afghanistan    NaN    NaN    NaN   NaN      NaN   NaN   NaN   NaN
# 1              Albania  96.10  136.4  108.5  96.1    96.11  93.0  83.7  77.5
# 2              Algeria    NaN    NaN    NaN   NaN  9300.00   NaN   NaN   NaN
# 3               Angola    NaN    NaN    NaN   NaN      NaN   NaN   NaN   NaN
# 4  Antigua and Barbuda   1.58    NaN    NaN   NaN      NaN   NaN   NaN   NaN
#
#    1998  ...    2014    2015    2016    2017    2018    2019   2020   2021  \
# 0   NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 1  74.4  ...  120.95  120.96  120.95  120.96  120.97  102.02  60.05  56.49
# 2   NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 3   NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 4   NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
#
#      2022    2023
# 0     NaN     NaN
# 1  107.12  103.62
# 2     NaN     NaN
# 3     NaN     NaN
# 4     NaN     NaN
#
# [5 rows x 35 columns]

# %%
df_emissions['NOx'].head()
# Out:
#                Country   1990   1991   1992   1993    1994   1995   1996  \
# 0          Afghanistan    NaN    NaN    NaN    NaN     NaN    NaN    NaN
# 1              Albania  17.85  21.11  15.63  16.16   18.85  18.17  18.16
# 2              Algeria    NaN    NaN    NaN    NaN  242.00    NaN    NaN
# 3               Angola    NaN    NaN    NaN    NaN     NaN    NaN    NaN
# 4  Antigua and Barbuda    NaN    NaN    NaN    NaN     NaN    NaN    NaN
#
#     1997  1998  ...  2014   2015   2016   2017  2018   2019   2020   2021  \
# 0    NaN   NaN  ...   NaN    NaN    NaN    NaN   NaN    NaN    NaN    NaN
# 1  19.37  23.7  ...  48.5  48.49  48.49  48.49  48.5  42.81  25.33  24.23
# 2    NaN   NaN  ...   NaN    NaN    NaN    NaN   NaN    NaN    NaN    NaN
# 3    NaN   NaN  ...   NaN    NaN    NaN    NaN   NaN    NaN    NaN    NaN
# 4    NaN   NaN  ...   NaN    NaN    NaN    NaN   NaN    NaN    NaN    NaN
#
#     2022   2023
# 0    NaN    NaN
# 1  44.95  43.55
# 2    NaN    NaN
# 3    NaN    NaN
# 4    NaN    NaN
#
# [5 rows x 35 columns]

# %%
df_emissions['SO2'].head()
# Out:
#                Country   1990  1991  1992  1993   1994  1995  1996   1997  \
# 0          Afghanistan    NaN   NaN   NaN   NaN    NaN   NaN   NaN    NaN
# 1              Albania   0.57  0.91   0.6  0.61   0.57  0.54  0.51   0.45
# 2              Algeria    NaN   NaN   NaN   NaN  39.69   NaN   NaN    NaN
# 3  Antigua and Barbuda   2.83   NaN   NaN   NaN    NaN   NaN   NaN    NaN
# 4            Argentina  79.20   NaN   NaN   NaN  99.97   NaN   NaN  96.37
#
#    1998  ...  2014  2015  2016  2017  2018  2019  2020  2021  2022  2023
# 0   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  0.43  ...  1.61   1.6  1.59   1.6  1.59  4.83  2.56  2.52  5.07  4.88
# 2   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 35 columns]

# %%
df_emissions['CH4'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 35 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  189 non-null    object
#  1   1990     90 non-null     float64
#  2   1991     65 non-null     float64
#  3   1992     67 non-null     float64
#  4   1993     70 non-null     float64
#  5   1994     150 non-null    float64
#  6   1995     79 non-null     float64
#  7   1996     71 non-null     float64
#  8   1997     72 non-null     float64
#  9   1998     74 non-null     float64
#  10  1999     69 non-null     float64
#  11  2000     150 non-null    float64
#  12  2001     69 non-null     float64
#  13  2002     73 non-null     float64
#  14  2003     73 non-null     float64
#  15  2004     74 non-null     float64
#  16  2005     88 non-null     float64
#  17  2006     78 non-null     float64
#  18  2007     71 non-null     float64
#  19  2008     70 non-null     float64
#  20  2009     68 non-null     float64
#  21  2010     89 non-null     float64
#  22  2011     65 non-null     float64
#  23  2012     75 non-null     float64
#  24  2013     67 non-null     float64
#  25  2014     62 non-null     float64
#  26  2015     61 non-null     float64
#  27  2016     58 non-null     float64
#  28  2017     55 non-null     float64
#  29  2018     53 non-null     float64
#  30  2019     45 non-null     float64
#  31  2020     45 non-null     float64
#  32  2021     45 non-null     float64
#  33  2022     45 non-null     float64
#  34  2023     45 non-null     float64
# dtypes: float64(34), object(1)
# memory usage: 52.1+ KB

# %% [markdown]
# ### Filtraggio dati che riguardano l'unione europea
#
# Nel nostro studio ci interessano solo i paesi dell'Unione Europea

# %%
def filter_eu_countries(df):
    '''Restituisce un nuovo DataFrame con solo i paesi dell'UE
    Reimposta gli indici del DataFrame in modo che ripartano da zero'''
    eu_countries = [
        'Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Cyprus',
        'Denmark', 'Estonia', 'Finland', 'France', 'Germany',
        'Greece', 'Hungary', 'Ireland', 'Italy', 'Latvia',
        'Lithuania', 'Luxembourg', 'Malta', 'Netherlands',
        'Poland', 'Portugal', 'Romania', 'Slovakia', 'Slovenia',
        'Spain', 'Sweden', 'Czechia'
    ]
    return df[df['Country'].isin(eu_countries)].reset_index(drop=True)

# Creo il dizionario che conterrà i dataframe filtrati
df_emissions_eu = {}

for gas, df in df_emissions.items():
    df_emissions_eu[gas] = filter_eu_countries(df)

# %%
display(df_emissions_eu['CO2'])
# Out:
#         Country        1990        1991       1992       1993       1994  \
# 0       Austria    62124.70    65725.53   60204.07   60635.42   61002.44
# 1       Belgium   120309.34   123382.08  122507.84  121444.20  124816.90
# 2      Bulgaria    76698.98    61232.60   57010.43   57675.64   56083.53
# 3       Croatia    23329.25    17182.30   16506.08   16959.78   16214.22
# 4        Cyprus     4656.89     5146.61    5522.91    5766.97    6011.11
# 5       Czechia   164204.21   148894.13  144619.02  138637.29  132376.14
# 6       Denmark    54845.67    65428.35   59595.59   61682.60   65699.57
# 4    Cyprus    4656.89    5146.61    5522.91    5766.97    6011.11    5882.27
#
#         1996       1997       1998  ...      2014       2015      2016  \
# 0   67421.59   67232.78   66875.15  ...  64084.43   66283.24  67112.27
# 1  129496.58  124001.76  130227.11  ...  96811.32  100981.34  99806.94
# 2   58108.02   55861.27   53275.22  ...  45169.33   48194.28  45353.72
# 3   17515.27   18575.88   19278.90  ...  17704.99   17840.75  18105.04
# 4    6233.23    6321.03    6614.65  ...   6934.59    6960.13   7368.23
#
#        2017       2018      2019      2020      2021      2022      2023
# 0  69628.86   66719.68  52987.01  31852.71  31493.55  55636.36  50369.68
# 1  99456.28  100207.84  85836.73  49974.71  48429.55  90128.57  76322.98
# 2  47505.16   43551.60  44449.88  26910.67  26818.86  46672.37  44510.37
# 3  18737.69   17718.65  14442.69   8673.47   9138.78  15164.82  14376.14
# 4   7515.69    7332.76   8865.16   5368.65   5355.52   9308.42   9018.22
#
# [5 rows x 35 columns]

# %% [markdown]
# ## **Analisi Descrittive sui Gas Serra**
#
# ### Identificare i Paesi più Inquinanti

# %%
def convert_values_to_numeric(df):
    """
    Converte i valori di tutte le colonne (tranne 'Country') di un DataFrame in tipo numerico.
    I valori non convertibili li sostituisce con NaN
    """
    df = df.copy() # Crea una copia per non modificare il df originale
    numeric_cols = []

    # Itera su tutte le colonne e converte in numerico
    for col in df.columns:
        if col != 'Country':
            df[col] = pd.to_numeric(df[col], errors='coerce') # 'coerece' sostituisce con NaN i valori non validi
            numeric_cols.append(col)
    return df, numeric_cols

def calculate_emissions(df, numeric_cols):
    '''Funzione che calcola le emissioni totali e medie di uno specifico gas serra'''
    df = df.copy() # Crea una copia per non modificare il df originale

    df['TotalEmissions'] = df[numeric_cols].sum(axis=1)
    df['AverageEmissions']=df[numeric_cols].mean(axis=1)

    return df

df_emissions_clean = {} # Nuovo dizionario che conterrà i dataframe puliti
conversion_report = {}

for gas, df in df_emissions_eu.items():
    df_clean, cols_converted = convert_values_to_numeric(df)
    df_emissions_clean[gas] = calculate_emissions(df_clean,cols_converted)
    conversion_report[gas] = cols_converted
    
    # Ordiniamo per totale delle emissioni
    sorted = df_emissions_clean[gas].sort_values(by='TotalEmissions', ascending=False)

    # Ordiniamo per media delle emissioni
    #sorted_mean = df_emissions_clean[gas].sort_values(by='AverageEmissions', ascending=False)
    
    # Istogramma totale delle emissioni
    plt.figure(figsize=(8, 5))
    sns.barplot(
        data = sorted,
        x = 'TotalEmissions',
        y = 'Country',
        color='skyblue'
    )
    plt.title(f'Emissioni totali per paese - {gas}')
    plt.xlabel('Emissioni totali')
    plt.ylabel('Paesi UE')
    plt.tight_layout()
    plt.show()

    # Istogramma media delle emissioni
    plt.figure(figsize=(8, 5))
    sns.barplot(
        data = sorted,
        x = 'AverageEmissions',
        y = 'Country',
        color='green'
    )
    plt.title(f'Emissioni totali per paese - {gas}')
    plt.xlabel('Emissioni totali')
    plt.ylabel('Paesi UE')
    plt.tight_layout()
    plt.show()
    # print(sorted_tot.head())

    # Creare visualizzazioni con solo i 5 paesi più inquinanti in ogni grafico, 
    # in modo da ridurre le dimensioni

# %% [markdown]
# ### Trend dele Emissioni di Gas Serra dal 1990 al 2023
